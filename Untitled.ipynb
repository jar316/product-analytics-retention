# %%
staging_sql = open("sql/01_staging.sql").read()
con.execute(staging_sql)
con.execute("SELECT COUNT(*) AS rows FROM stg_retail").df()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/mp/3trsgpw928z7bw3t1zmlkp9h0000gn/T/ipykernel_14539/4138892816.py in <module>
#       1 staging_sql = open("sql/01_staging.sql").read()
# ----> 2 con.execute(staging_sql)
#       3 con.execute("SELECT COUNT(*) AS rows FROM stg_retail").df()
#
# NameError: name 'con' is not defined
